# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np 
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE 
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import clear_output
from tensorflow.keras.optimizers import Adam 
from sklearn.model_selection import train_test_split

# %%
train_imgs_path = "../input/3dircadb/3DIRCADB/train/Images/"
train_masks_path = "../input/3dircadb/3DIRCADB/train/Masks"
test_imgs_path = "../input/3dircadb/3DIRCADB/test/Images"
test_masks_path = "../input/3dircadb/3DIRCADB/test/Masks"

# %%
img = cv2.imread("../input/3dircadb/3DIRCADB/train/Images/images/image_100.png")
plt.imshow(img)
print(img.shape, np.amin(img), np.amax(img))
# Out:
# (512, 512, 3) 0 255

# %%
img = cv2.imread("../input/3dircadb/3DIRCADB/test/Masks/masks/mask_100.png")
plt.imshow(img)
print(img.shape, np.amin(img), np.amax(img))
# Out:
# (512, 512, 3) 0 255

# %%
from tensorflow.keras.models import *
from tensorflow.python.keras.utils.data_utils import Sequence
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
def adjustData(img,mask,flag_multi_class,num_class):
    if(flag_multi_class):
        img = img / 255
        mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
        new_mask = np.zeros(mask.shape + (num_class,))
        for i in range(num_class):
            #for one pixel in the image, find the class in mask and convert it into one-hot vector
            #index = np.where(mask == i)
            #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
            #new_mask[index_mask] = 1
            new_mask[mask == i,i] = 1
        new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
        mask = new_mask
    elif(np.max(img) > 1):
        img = img / 255
        mask = mask /255
        mask[mask > 0.5] = 1
        mask[mask <= 0.5] = 0
    return (img,mask)
def trainGenerator(batch_size,train_path,image_folder,
                   mask_folder,
                   aug_dict,
                   image_color_mode = "grayscale",
                   mask_color_mode = "grayscale",
                   image_save_prefix  = "image",
                   mask_save_prefix  = "mask",
                   flag_multi_class = False,
                   num_class = 2,
                   save_to_dir = None,
                   target_size = (256,256),
                   seed = 1,
                   subset = 'training'):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed,
        subset = subset)
    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed,
        subset = subset)
    train_generator = zip(image_generator, mask_generator)
    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,flag_multi_class,num_class)
        yield (img,mask)

# %%
data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest',
                    validation_split=0.2)
train_generator = trainGenerator(16,'../input/3dircadb/3DIRCADB/train','Images','Masks',data_gen_args,save_to_dir = None,
                                target_size = (512,512))
valid_generator = trainGenerator(16,'../input/3dircadb/3DIRCADB/train','Images','Masks',data_gen_args,save_to_dir = None,subset = 'validation',
                                target_size = (512,512))

# %%
def display(display_list):
    plt.figure(figsize=(15,15))
    
    title = ['Input Image', 'True Mask', 'Predicted Mask']
    
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap='gray')
    plt.show()

# %%
def show_dataset(datagen, num=1):
    for i in range(0,num):
        image,mask = next(datagen)
        display([image[0], mask[0]])

# %%
show_dataset(train_generator, 5)
# Out:
# Found 1647 images belonging to 1 classes.
# Found 1647 images belonging to 1 classes.

# %%
show_dataset(valid_generator, 5)
# Out:
# Found 411 images belonging to 1 classes.
# Found 411 images belonging to 1 classes.

# %%
model = unet(input_size=(512,512,1))
model.summary()
# Out:
# 2022-02-23 14:07:46.964334: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 256)  524544      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 128 295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 1)  33          conv2d_17[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2022-02-23 14:07:47.062895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:47.063625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:47.064771: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-23 14:07:47.066026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:47.066678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:47.067319: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:48.986159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:48.987026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:48.987647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-23 14:07:48.988227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.compile(optimizer=Adam(learning_rate=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
# model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early]

# %%
num_train = 1647
num_valid = 411
train_batchsize = 16
valid_batchsize = 16
Step_train = num_train // train_batchsize
Step_valid = num_valid // valid_batchsize
epochs = 100

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=Step_train,
    epochs=epochs,
    validation_data=valid_generator,
    validation_steps=Step_valid,
    verbose=1,
    callbacks=callbacks_list
)
# Out:
# 2022-02-23 14:07:51.203677: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-02-23 14:07:53.422216: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 102/102 [==============================] - 128s 1s/step - loss: -0.0782 - dice_coef: 0.0782 - binary_accuracy: 0.6895 - val_loss: -0.0648 - val_dice_coef: 0.0650 - val_binary_accuracy: 0.7346
#
# Epoch 00001: val_loss improved from inf to -0.06482, saving model to cxr_reg_weights.best.hdf5
# Epoch 2/100
# 102/102 [==============================] - 94s 930ms/step - loss: -0.0895 - dice_coef: 0.0895 - binary_accuracy: 0.6615 - val_loss: -0.0895 - val_dice_coef: 0.0894 - val_binary_accuracy: 0.3889
#
# Epoch 00002: val_loss improved from -0.06482 to -0.08950, saving model to cxr_reg_weights.best.hdf5
# Epoch 3/100
# 102/102 [==============================] - 94s 931ms/step - loss: -0.1297 - dice_coef: 0.1297 - binary_accuracy: 0.6797 - val_loss: -0.1071 - val_dice_coef: 0.1075 - val_binary_accuracy: 0.9431
#
# Epoch 00003: val_loss improved from -0.08950 to -0.10707, saving model to cxr_reg_weights.best.hdf5
# Epoch 4/100
# 102/102 [==============================] - 95s 935ms/step - loss: -0.4917 - dice_coef: 0.4918 - binary_accuracy: 0.9545 - val_loss: -0.6315 - val_dice_coef: 0.6320 - val_binary_accuracy: 0.9754
#
# Epoch 00004: val_loss improved from -0.10707 to -0.63147, saving model to cxr_reg_weights.best.hdf5
# Epoch 5/100
# 102/102 [==============================] - 95s 940ms/step - loss: -0.6206 - dice_coef: 0.6206 - binary_accuracy: 0.9653 - val_loss: -0.6408 - val_dice_coef: 0.6422 - val_binary_accuracy: 0.9801
#
# Epoch 00005: val_loss improved from -0.63147 to -0.64076, saving model to cxr_reg_weights.best.hdf5
# Epoch 6/100
# 102/102 [==============================] - 95s 935ms/step - loss: -0.6256 - dice_coef: 0.6256 - binary_accuracy: 0.9660 - val_loss: -0.6345 - val_dice_coef: 0.6349 - val_binary_accuracy: 0.9765
#
# Epoch 00006: val_loss did not improve from -0.64076
# Epoch 7/100
# 102/102 [==============================] - 95s 934ms/step - loss: -0.6360 - dice_coef: 0.6360 - binary_accuracy: 0.9661 - val_loss: -0.6639 - val_dice_coef: 0.6653 - val_binary_accuracy: 0.9793
#
# Epoch 00007: val_loss improved from -0.64076 to -0.66393, saving model to cxr_reg_weights.best.hdf5
# Epoch 8/100
# 102/102 [==============================] - 96s 942ms/step - loss: -0.6526 - dice_coef: 0.6527 - binary_accuracy: 0.9686 - val_loss: -0.6340 - val_dice_coef: 0.6345 - val_binary_accuracy: 0.9791
#
# Epoch 00008: val_loss did not improve from -0.66393
# Epoch 9/100
# 102/102 [==============================] - 94s 929ms/step - loss: -0.6679 - dice_coef: 0.6679 - binary_accuracy: 0.9693 - val_loss: -0.6743 - val_dice_coef: 0.6742 - val_binary_accuracy: 0.9808
#
# Epoch 00009: val_loss improved from -0.66393 to -0.67432, saving model to cxr_reg_weights.best.hdf5
# Epoch 10/100
# 102/102 [==============================] - 94s 923ms/step - loss: -0.6809 - dice_coef: 0.6809 - binary_accuracy: 0.9714 - val_loss: -0.6734 - val_dice_coef: 0.6751 - val_binary_accuracy: 0.9795
#
# Epoch 00010: val_loss did not improve from -0.67432
# Epoch 11/100
# 102/102 [==============================] - 95s 937ms/step - loss: -0.7003 - dice_coef: 0.7004 - binary_accuracy: 0.9730 - val_loss: -0.6791 - val_dice_coef: 0.6784 - val_binary_accuracy: 0.9816
#
# Epoch 00011: val_loss improved from -0.67432 to -0.67907, saving model to cxr_reg_weights.best.hdf5
# Epoch 12/100
# 102/102 [==============================] - 94s 929ms/step - loss: -0.7093 - dice_coef: 0.7093 - binary_accuracy: 0.9737 - val_loss: -0.7087 - val_dice_coef: 0.7075 - val_binary_accuracy: 0.9792
#
# Epoch 00012: val_loss improved from -0.67907 to -0.70868, saving model to cxr_reg_weights.best.hdf5
# Epoch 13/100
# 102/102 [==============================] - 95s 931ms/step - loss: -0.7182 - dice_coef: 0.7182 - binary_accuracy: 0.9749 - val_loss: -0.6861 - val_dice_coef: 0.6844 - val_binary_accuracy: 0.9826
#
# Epoch 00013: val_loss did not improve from -0.70868
# Epoch 14/100
# 102/102 [==============================] - 94s 931ms/step - loss: -0.7270 - dice_coef: 0.7271 - binary_accuracy: 0.9755 - val_loss: -0.7304 - val_dice_coef: 0.7317 - val_binary_accuracy: 0.9830
#
# Epoch 00014: val_loss improved from -0.70868 to -0.73035, saving model to cxr_reg_weights.best.hdf5
# Epoch 15/100
# 102/102 [==============================] - 94s 930ms/step - loss: -0.7239 - dice_coef: 0.7239 - binary_accuracy: 0.9747 - val_loss: -0.7002 - val_dice_coef: 0.6994 - val_binary_accuracy: 0.9776
#
# Epoch 00015: val_loss did not improve from -0.73035
# Epoch 16/100
# 102/102 [==============================] - 95s 932ms/step - loss: -0.7386 - dice_coef: 0.7386 - binary_accuracy: 0.9767 - val_loss: -0.7237 - val_dice_coef: 0.7230 - val_binary_accuracy: 0.9848
#
# Epoch 00016: val_loss did not improve from -0.73035
# Epoch 17/100
# 102/102 [==============================] - 95s 938ms/step - loss: -0.7297 - dice_coef: 0.7297 - binary_accuracy: 0.9762 - val_loss: -0.7351 - val_dice_coef: 0.7351 - val_binary_accuracy: 0.9856
#
# Epoch 00017: val_loss improved from -0.73035 to -0.73513, saving model to cxr_reg_weights.best.hdf5
# Epoch 18/100
# 102/102 [==============================] - 95s 936ms/step - loss: -0.7279 - dice_coef: 0.7280 - binary_accuracy: 0.9763 - val_loss: -0.7584 - val_dice_coef: 0.7582 - val_binary_accuracy: 0.9840
#
# Epoch 00018: val_loss improved from -0.73513 to -0.75841, saving model to cxr_reg_weights.best.hdf5
# Epoch 19/100
# 102/102 [==============================] - 95s 939ms/step - loss: -0.7485 - dice_coef: 0.7485 - binary_accuracy: 0.9776 - val_loss: -0.7247 - val_dice_coef: 0.7256 - val_binary_accuracy: 0.9823
#
# Epoch 00019: val_loss did not improve from -0.75841
# Epoch 20/100
# 102/102 [==============================] - 96s 941ms/step - loss: -0.7396 - dice_coef: 0.7395 - binary_accuracy: 0.9775 - val_loss: -0.7213 - val_dice_coef: 0.7220 - val_binary_accuracy: 0.9848
#
# Epoch 00020: val_loss did not improve from -0.75841
# Epoch 21/100
# 102/102 [==============================] - 96s 944ms/step - loss: -0.7512 - dice_coef: 0.7512 - binary_accuracy: 0.9780 - val_loss: -0.7518 - val_dice_coef: 0.7520 - val_binary_accuracy: 0.9842
#
# Epoch 00021: val_loss did not improve from -0.75841
# Epoch 22/100
# 102/102 [==============================] - 95s 933ms/step - loss: -0.7399 - dice_coef: 0.7399 - binary_accuracy: 0.9774 - val_loss: -0.7418 - val_dice_coef: 0.7430 - val_binary_accuracy: 0.9848
#
# Epoch 00022: val_loss did not improve from -0.75841
# Epoch 23/100
# 102/102 [==============================] - 95s 935ms/step - loss: -0.7547 - dice_coef: 0.7547 - binary_accuracy: 0.9780 - val_loss: -0.7551 - val_dice_coef: 0.7551 - val_binary_accuracy: 0.9860
#
# Epoch 00023: val_loss did not improve from -0.75841
# Epoch 24/100
# 102/102 [==============================] - 94s 930ms/step - loss: -0.7558 - dice_coef: 0.7558 - binary_accuracy: 0.9782 - val_loss: -0.7607 - val_dice_coef: 0.7593 - val_binary_accuracy: 0.9853
#
# Epoch 00024: val_loss improved from -0.75841 to -0.76068, saving model to cxr_reg_weights.best.hdf5
# Epoch 25/100
# 102/102 [==============================] - 95s 933ms/step - loss: -0.7514 - dice_coef: 0.7514 - binary_accuracy: 0.9786 - val_loss: -0.7518 - val_dice_coef: 0.7525 - val_binary_accuracy: 0.9849
#
# Epoch 00025: val_loss did not improve from -0.76068
# Epoch 26/100
# 102/102 [==============================] - 95s 933ms/step - loss: -0.7519 - dice_coef: 0.7519 - binary_accuracy: 0.9777 - val_loss: -0.7520 - val_dice_coef: 0.7527 - val_binary_accuracy: 0.9870
#
# Epoch 00026: val_loss did not improve from -0.76068
# Epoch 27/100
# 102/102 [==============================] - 95s 937ms/step - loss: -0.7465 - dice_coef: 0.7466 - binary_accuracy: 0.9782 - val_loss: -0.7537 - val_dice_coef: 0.7544 - val_binary_accuracy: 0.9851
#
# Epoch 00027: val_loss did not improve from -0.76068
# Epoch 28/100
# 102/102 [==============================] - 95s 939ms/step - loss: -0.7572 - dice_coef: 0.7572 - binary_accuracy: 0.9785 - val_loss: -0.7702 - val_dice_coef: 0.7706 - val_binary_accuracy: 0.9869
#
# Epoch 00028: val_loss improved from -0.76068 to -0.77025, saving model to cxr_reg_weights.best.hdf5
# Epoch 29/100
# 102/102 [==============================] - 96s 941ms/step - loss: -0.7539 - dice_coef: 0.7540 - binary_accuracy: 0.9788 - val_loss: -0.7640 - val_dice_coef: 0.7634 - val_binary_accuracy: 0.9853
#
# Epoch 00029: val_loss did not improve from -0.77025
# Epoch 30/100
# 102/102 [==============================] - 96s 947ms/step - loss: -0.7631 - dice_coef: 0.7632 - binary_accuracy: 0.9793 - val_loss: -0.7722 - val_dice_coef: 0.7729 - val_binary_accuracy: 0.9876
#
# Epoch 00030: val_loss improved from -0.77025 to -0.77216, saving model to cxr_reg_weights.best.hdf5
# Epoch 31/100
# 102/102 [==============================] - 95s 934ms/step - loss: -0.7623 - dice_coef: 0.7623 - binary_accuracy: 0.9794 - val_loss: -0.7779 - val_dice_coef: 0.7783 - val_binary_accuracy: 0.9886
#
# Epoch 00031: val_loss improved from -0.77216 to -0.77786, saving model to cxr_reg_weights.best.hdf5
# Epoch 32/100
# 102/102 [==============================] - 95s 938ms/step - loss: -0.7634 - dice_coef: 0.7634 - binary_accuracy: 0.9790 - val_loss: -0.7681 - val_dice_coef: 0.7688 - val_binary_accuracy: 0.9870
#
# Epoch 00032: val_loss did not improve from -0.77786
# Epoch 33/100
# 102/102 [==============================] - 96s 944ms/step - loss: -0.7620 - dice_coef: 0.7620 - binary_accuracy: 0.9802 - val_loss: -0.7730 - val_dice_coef: 0.7725 - val_binary_accuracy: 0.9868
#
# Epoch 00033: val_loss did not improve from -0.77786
# Epoch 34/100
# 102/102 [==============================] - 96s 944ms/step - loss: -0.7673 - dice_coef: 0.7672 - binary_accuracy: 0.9790 - val_loss: -0.7883 - val_dice_coef: 0.7893 - val_binary_accuracy: 0.9880
#
# Epoch 00034: val_loss improved from -0.77786 to -0.78834, saving model to cxr_reg_weights.best.hdf5
# Epoch 35/100
# 102/102 [==============================] - 95s 939ms/step - loss: -0.7691 - dice_coef: 0.7692 - binary_accuracy: 0.9797 - val_loss: -0.7913 - val_dice_coef: 0.7924 - val_binary_accuracy: 0.9870
#
# Epoch 00035: val_loss improved from -0.78834 to -0.79126, saving model to cxr_reg_weights.best.hdf5
# Epoch 36/100
# 102/102 [==============================] - 96s 944ms/step - loss: -0.7792 - dice_coef: 0.7792 - binary_accuracy: 0.9805 - val_loss: -0.7697 - val_dice_coef: 0.7705 - val_binary_accuracy: 0.9855
#
# Epoch 00036: val_loss did not improve from -0.79126
# Epoch 37/100
# 102/102 [==============================] - 96s 945ms/step - loss: -0.7581 - dice_coef: 0.7582 - binary_accuracy: 0.9798 - val_loss: -0.7676 - val_dice_coef: 0.7671 - val_binary_accuracy: 0.9846
#
# Epoch 00037: val_loss did not improve from -0.79126
# Epoch 38/100
# 102/102 [==============================] - 95s 937ms/step - loss: -0.7670 - dice_coef: 0.7669 - binary_accuracy: 0.9789 - val_loss: -0.7841 - val_dice_coef: 0.7816 - val_binary_accuracy: 0.9873
#
# Epoch 00038: val_loss did not improve from -0.79126
# Epoch 39/100
# 102/102 [==============================] - 96s 945ms/step - loss: -0.7866 - dice_coef: 0.7866 - binary_accuracy: 0.9806 - val_loss: -0.8116 - val_dice_coef: 0.8111 - val_binary_accuracy: 0.9878
#
# Epoch 00039: val_loss improved from -0.79126 to -0.81161, saving model to cxr_reg_weights.best.hdf5
# Epoch 40/100
# 102/102 [==============================] - 97s 953ms/step - loss: -0.7784 - dice_coef: 0.7784 - binary_accuracy: 0.9814 - val_loss: -0.7763 - val_dice_coef: 0.7765 - val_binary_accuracy: 0.9882
#
# Epoch 00040: val_loss did not improve from -0.81161
# Epoch 41/100
# 102/102 [==============================] - 96s 946ms/step - loss: -0.7834 - dice_coef: 0.7834 - binary_accuracy: 0.9806 - val_loss: -0.7814 - val_dice_coef: 0.7810 - val_binary_accuracy: 0.9877
#
# Epoch 00041: val_loss did not improve from -0.81161
# Epoch 42/100
# 102/102 [==============================] - 96s 941ms/step - loss: -0.7620 - dice_coef: 0.7620 - binary_accuracy: 0.9804 - val_loss: -0.7880 - val_dice_coef: 0.7867 - val_binary_accuracy: 0.9888
#
# Epoch 00042: val_loss did not improve from -0.81161
# Epoch 43/100
# 102/102 [==============================] - 97s 957ms/step - loss: -0.7854 - dice_coef: 0.7854 - binary_accuracy: 0.9812 - val_loss: -0.7669 - val_dice_coef: 0.7672 - val_binary_accuracy: 0.9880
#
# Epoch 00043: val_loss did not improve from -0.81161
# Epoch 44/100
# 102/102 [==============================] - 95s 938ms/step - loss: -0.7877 - dice_coef: 0.7877 - binary_accuracy: 0.9813 - val_loss: -0.7774 - val_dice_coef: 0.7784 - val_binary_accuracy: 0.9879
#
# Epoch 00044: val_loss did not improve from -0.81161
# Epoch 45/100
# 102/102 [==============================] - 96s 942ms/step - loss: -0.7842 - dice_coef: 0.7843 - binary_accuracy: 0.9816 - val_loss: -0.7923 - val_dice_coef: 0.7929 - val_binary_accuracy: 0.9862
#
# Epoch 00045: val_loss did not improve from -0.81161
# Epoch 46/100
# 102/102 [==============================] - 97s 952ms/step - loss: -0.7864 - dice_coef: 0.7864 - binary_accuracy: 0.9807 - val_loss: -0.7743 - val_dice_coef: 0.7734 - val_binary_accuracy: 0.9883
#
# Epoch 00046: val_loss did not improve from -0.81161
# Epoch 47/100
# 102/102 [==============================] - 96s 948ms/step - loss: -0.7754 - dice_coef: 0.7753 - binary_accuracy: 0.9801 - val_loss: -0.7839 - val_dice_coef: 0.7847 - val_binary_accuracy: 0.9890
#
# Epoch 00047: val_loss did not improve from -0.81161
# Epoch 48/100
# 102/102 [==============================] - 96s 950ms/step - loss: -0.7926 - dice_coef: 0.7926 - binary_accuracy: 0.9818 - val_loss: -0.7763 - val_dice_coef: 0.7776 - val_binary_accuracy: 0.9881
#
# Epoch 00048: val_loss did not improve from -0.81161
# Epoch 49/100
# 102/102 [==============================] - 95s 939ms/step - loss: -0.8037 - dice_coef: 0.8037 - binary_accuracy: 0.9826 - val_loss: -0.7957 - val_dice_coef: 0.7969 - val_binary_accuracy: 0.9886
#
# Epoch 00049: val_loss did not improve from -0.81161
# Epoch 50/100
# 102/102 [==============================] - 96s 943ms/step - loss: -0.7781 - dice_coef: 0.7780 - binary_accuracy: 0.9815 - val_loss: -0.8026 - val_dice_coef: 0.8020 - val_binary_accuracy: 0.9893
#
# Epoch 00050: val_loss did not improve from -0.81161
# Epoch 51/100
# 102/102 [==============================] - 97s 955ms/step - loss: -0.7825 - dice_coef: 0.7825 - binary_accuracy: 0.9807 - val_loss: -0.7799 - val_dice_coef: 0.7799 - val_binary_accuracy: 0.9881
#
# Epoch 00051: val_loss did not improve from -0.81161
# Epoch 52/100
# 102/102 [==============================] - 97s 957ms/step - loss: -0.7885 - dice_coef: 0.7886 - binary_accuracy: 0.9822 - val_loss: -0.7927 - val_dice_coef: 0.7931 - val_binary_accuracy: 0.9876
#
# Epoch 00052: val_loss did not improve from -0.81161
# Epoch 53/100
# 102/102 [==============================] - 96s 942ms/step - loss: -0.7991 - dice_coef: 0.7992 - binary_accuracy: 0.9829 - val_loss: -0.7889 - val_dice_coef: 0.7893 - val_binary_accuracy: 0.9884
#
# Epoch 00053: val_loss did not improve from -0.81161
# Epoch 54/100
# 102/102 [==============================] - 96s 949ms/step - loss: -0.7962 - dice_coef: 0.7963 - binary_accuracy: 0.9826 - val_loss: -0.7906 - val_dice_coef: 0.7907 - val_binary_accuracy: 0.9863
#
# Epoch 00054: val_loss did not improve from -0.81161

# %% [markdown]
# Phân đoạn cho một loạt ảnh sử dụng ImageDataGenerator

# %%
data_gen_args = dict(
                    fill_mode='nearest',
                    validation_split=0)
test_generator = trainGenerator(1,'../input/3dircadb/3DIRCADB/test','Images','Masks',data_gen_args,save_to_dir = None,
                                target_size = (512,512))

# %%
show_dataset(test_generator, 5)
# Out:
# Found 765 images belonging to 1 classes.
# Found 765 images belonging to 1 classes.

# %%
results = model.predict_generator(test_generator,765,verbose=1)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# 765/765 [==============================] - 14s 17ms/step

# %%
results.shape
# Out:
# (765, 512, 512, 1)

# %%
results[results >= 0.5] = 255
results[results < 0.5] = 0
results = np.asarray(results, np.uint8)

# %%
plt.imshow(results[5])

# %% [markdown]
# Phân đoạn cho từng ảnh một

# %%
img = cv2.imread('../input/3dircadb/3DIRCADB/test/Images/images/image_5.png')
img = img/255
image = img[:,:,0]
image_tensor = tf.convert_to_tensor(image, dtype=tf.float32)
image_tensor = tf.expand_dims(image_tensor, 0)
mask = model.predict(image_tensor)
mask[mask >= 0.5] = 255
mask[mask < 0.5] = 0
mask = np.asarray(mask, np.uint8)
print('Ảnh dự đoán và true mask: ')
plt.subplot(1,2,1)
plt.imshow(mask[0])
plt.subplot(1,2,2)
true_mask = cv2.imread('../input/3dircadb/3DIRCADB/test/Masks/masks/mask_5.png')
_true_mask = true_mask[:,:,0]
plt.imshow(_true_mask)
# Out:
# Ảnh dự đoán và true mask:
